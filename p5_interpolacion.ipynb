# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados

# UTILICE:
# ajustar_min_cuadrados()
# Out:
# [01-28 23:20:03][INFO][Jonathan Zea] 2026-01-28 23:20:03.302467
# [01-28 23:20:03][INFO][Jonathan Zea] 2026-01-28 23:20:03.564456
# [01-28 23:20:03][INFO][Jonathan Zea] 2026-01-28 23:20:03.564456

# %%
# Reemplace con el conjunto de datos dado
# --- Datos de ejemplo
datos = [(4.1,5.4), (3.6,5.4), (3.3,5.3), (0.2,5.0), (9.8,6.1),
         (9.5,6.0), (3.2,5.3), (5.8,5.5), (0.7,5.2), (4.2,5.4),
         (5.4,5.7), (6.3,5.7), (0.3,5.1), (1.0,5.3), (9.3,5.7),
         (2.4,5.2), (4.7,5.5), (8.8,6.0), (5.2,5.5), (5.6,5.7),
         (4.8,5.5), (9.7,6.1), (7.5,5.9), (0.7,5.1), (8.2,5.9),
         (0.6,5.0), (2.3,5.3), (8.4,5.6), (0.4,5.1), (1.6,5.1),
         (1.5,5.1), (9.6,6.0), (6.6,5.5), (0.9,5.0), (8.2,6.1),
         (5.5,5.5), (9.4,5.9), (4.3,5.4), (6.4,5.6), (3.3,5.5),
         (2.8,5.3), (3.3,5.2), (0.9,5.3), (5.8,5.7), (4.3,5.5),
         (1.0,5.1), (5.4,5.5), (8.0,5.9), (8.6,5.8), (4.0,5.4),
         (8.9,5.8), (3.0,5.4), (9.2,5.9), (3.3,5.3), (8.9,5.9),
         (2.3,5.1), (1.9,5.1), (3.5,5.5), (4.3,5.4), (5.8,5.5),
         (8.9,5.9), (0.7,5.1), (5.8,5.6), (6.2,5.7), (2.4,5.3),
         (1.5,5.1), (0.2,5.1), (3.1,5.3), (6.2,5.6), (4.5,5.4),
         (3.1,5.3), (1.3,5.1), (2.0,5.3), (0.4,5.1),
         (5.4,5.5), (4.6,5.6), (0.6,4.9), (1.6,5.2), (1.9,5.2),
         (2.2,5.4), (6.4,5.5), (1.1,5.0), (7.9,5.8), (8.1,5.6),
         (3.8,5.3), (1.1,4.9), (3.0,5.4), (5.6,5.6), (5.4,5.5),
         (0.3,5.1), (8.3,6.1), (8.5,5.8), (5.3,5.6), (1.5,5.1),
         (0.9,5.1), (2.7,5.3), (3.0,5.3), (8.0,5.7), (2.0,5.2),
         (9.4,6.0)]

xs = [x for x, y in datos]
ys = [y for x, y in datos]

# %%
# Reemplace con la función obtenida de ajustar_min_cuadrados
interpolacion = lambda x: 0.09994*x + 5.011
# --- Función de ejemplo

import matplotlib.pyplot as plt
import numpy as np

# Dibujar los puntos x, y
plt.scatter(xs, ys, alpha=0.5, label="Datos")

coeficientes = np.polyfit(xs, ys, 1)
polinomio = np.poly1d(coeficientes)

# Dibujar la función de aproximación
x_aprox = np.linspace(min(xs), max(xs), 100)
y_aprox = [interpolacion(xi) for xi in x_aprox]
plt.plot(x_aprox, y_aprox, "r-", label="Interpolación: y = ")

plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Elimine un valor atipico (-200.0,500)

datos = [(4.1,5.4), (3.6,5.4), (3.3,5.3), (0.2,5.0), (9.8,6.1),
         (9.5,6.0), (3.2,5.3), (5.8,5.5), (0.7,5.2), (4.2,5.4),
         (5.4,5.7), (6.3,5.7), (0.3,5.1), (1.0,5.3), (9.3,5.7),
         (2.4,5.2), (4.7,5.5), (8.8,6.0), (5.2,5.5), (5.6,5.7),
         (4.8,5.5), (9.7,6.1), (7.5,5.9), (0.7,5.1), (8.2,5.9),
         (0.6,5.0), (2.3,5.3), (8.4,5.6), (0.4,5.1), (1.6,5.1),
         (1.5,5.1), (9.6,6.0), (6.6,5.5), (0.9,5.0), (8.2,6.1),
         (5.5,5.5), (9.4,5.9), (4.3,5.4), (6.4,5.6), (3.3,5.5),
         (2.8,5.3), (3.3,5.2), (0.9,5.3), (5.8,5.7), (4.3,5.5),
         (1.0,5.1), (5.4,5.5), (8.0,5.9), (8.6,5.8), (4.0,5.4),
         (8.9,5.8), (3.0,5.4), (9.2,5.9), (3.3,5.3), (8.9,5.9),
         (2.3,5.1), (1.9,5.1), (3.5,5.5), (4.3,5.4), (5.8,5.5),
         (8.9,5.9), (0.7,5.1), (5.8,5.6), (6.2,5.7), (2.4,5.3),
         (1.5,5.1), (0.2,5.1), (3.1,5.3), (6.2,5.6), (4.5,5.4),
         (3.1,5.3), (1.3,5.1), (2.0,5.3), (-200.0,500), (0.4,5.1),
         (5.4,5.5), (4.6,5.6), (0.6,4.9), (1.6,5.2), (1.9,5.2),
         (2.2,5.4), (6.4,5.5), (1.1,5.0), (7.9,5.8), (8.1,5.6),
         (3.8,5.3), (1.1,4.9), (3.0,5.4), (5.6,5.6), (5.4,5.5),
         (0.3,5.1), (8.3,6.1), (8.5,5.8), (5.3,5.6), (1.5,5.1),
         (0.9,5.1), (2.7,5.3), (3.0,5.3), (8.0,5.7), (2.0,5.2),
         (9.4,6.0)]

xs = [x for x, y in datos]
ys = [y for x, y in datos]

plt.figure(figsize=(8,6))

plt.scatter(xs, ys)   

plt.title("Gráfico con valor atípico (-200.0,500)")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Elimine un valor atipico (-200.0,500)

datos = [(4.1,5.4), (3.6,5.4), (3.3,5.3), (0.2,5.0), (9.8,6.1),
         (9.5,6.0), (3.2,5.3), (5.8,5.5), (0.7,5.2), (4.2,5.4),
         (5.4,5.7), (6.3,5.7), (0.3,5.1), (1.0,5.3), (9.3,5.7),
         (2.4,5.2), (4.7,5.5), (8.8,6.0), (5.2,5.5), (5.6,5.7),
         (4.8,5.5), (9.7,6.1), (7.5,5.9), (0.7,5.1), (8.2,5.9),
         (0.6,5.0), (2.3,5.3), (8.4,5.6), (0.4,5.1), (1.6,5.1),
         (1.5,5.1), (9.6,6.0), (6.6,5.5), (0.9,5.0), (8.2,6.1),
         (5.5,5.5), (9.4,5.9), (4.3,5.4), (6.4,5.6), (3.3,5.5),
         (2.8,5.3), (3.3,5.2), (0.9,5.3), (5.8,5.7), (4.3,5.5),
         (1.0,5.1), (5.4,5.5), (8.0,5.9), (8.6,5.8), (4.0,5.4),
         (8.9,5.8), (3.0,5.4), (9.2,5.9), (3.3,5.3), (8.9,5.9),
         (2.3,5.1), (1.9,5.1), (3.5,5.5), (4.3,5.4), (5.8,5.5),
         (8.9,5.9), (0.7,5.1), (5.8,5.6), (6.2,5.7), (2.4,5.3),
         (1.5,5.1), (0.2,5.1), (3.1,5.3), (6.2,5.6), (4.5,5.4),
         (3.1,5.3), (1.3,5.1), (2.0,5.3) , (0.4,5.1),
         (5.4,5.5), (4.6,5.6), (0.6,4.9), (1.6,5.2), (1.9,5.2),
         (2.2,5.4), (6.4,5.5), (1.1,5.0), (7.9,5.8), (8.1,5.6),
         (3.8,5.3), (1.1,4.9), (3.0,5.4), (5.6,5.6), (5.4,5.5),
         (0.3,5.1), (8.3,6.1), (8.5,5.8), (5.3,5.6), (1.5,5.1),
         (0.9,5.1), (2.7,5.3), (3.0,5.3), (8.0,5.7), (2.0,5.2),
         (9.4,6.0)]

xs = [x for x, y in datos]
ys = [y for x, y in datos]

plt.figure(figsize=(8,6))

plt.scatter(xs, ys)   

plt.title("Gráfico de dispersión sin valor atípico (-200.0,500)")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

coeficientes = np.polyfit(xs, ys, 1)
polinomio = np.poly1d(coeficientes)

interpolacion = polinomio

print("Polinomio de grado 1:")
print(polinomio)

# Dibujar los puntos x, y
plt.figure(figsize=(10, 6))
plt.scatter(xs, ys, alpha=0.5, label="Datos", color="blue")

# Dibujar la función de aproximación
x_aprox = np.linspace(min(xs), max(xs), 300)
y_aprox = polinomio(x_aprox)
plt.plot(x_aprox, y_aprox, "r-", label="Polinomio de grado 1", linewidth=2)

plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolación con Polinomio de Grado 1")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Polinomio de grado 1:
#
# 0.09994 x + 5.011

# %%
# Valores aproximados
y_aprox = polinomio(xs)

# Error relativo en cada punto
error_rel = np.abs((ys - y_aprox) / ys)

# 1) Error relativo promedio
e_rel = np.mean(error_rel)

# 2) Máximo error relativo
e_max = np.max(error_rel)

print("Error relativo promedio:", e_rel)
print("Máximo error relativo:", e_max)
# Out:
# Error relativo promedio: 0.014186571331741102
# Máximo error relativo: 0.04506178358541155
